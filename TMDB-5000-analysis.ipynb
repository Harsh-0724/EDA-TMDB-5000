# %% [markdown]
# ## EDA PROJECT- Analysing and producing the Exploratory Data Analysis of the TMDB 5000 movie dataset using success of movies as a factor.
#
# ##### By: Harsh Agrawal

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib 
import matplotlib.pyplot as plt

# %% [markdown]
# #### READING THE DATASET:-

# %%
df = pd.read_csv("C:\\Users\\agraw\\Desktop\\EL\\python theory EL\\tmdb_5000_movies.csv")
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # DATA CLEANING:-
# NOTE: Dropping all the null values and using minimum budget as 10000 for data analysis.So all the movies with budget less than 10000 have been removed from the dataset.

# %%
df.drop(df.index[(df["budget"] < 10000)],axis=0,inplace=True)
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4774      27000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4781      22000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %%
df.drop("index",axis=1,inplace=True) 
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.drop("index",axis=1,inplace=True)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %% [markdown]
# # DATA ANALYSIS
#
# ### MAPPING, RENAMING AND FILTERING THE DATASET:-
# NOTE: Remapping the column names for better readability and filtering only the parameters necessary for determining the success of a movie.

# %%
column_mapping = {                                                 #Renaming, mapping and filtering and printing the dataset
    'level_0' : 'Serial Number',
    'index' : 'Index',
    'budget' : 'Budget',
    'genres' : 'Genres',
    'homepage' : 'Homepage',
    'id' : 'ID',
    'keywords' : 'Keywords',
    'original_language' : 'Original Language',
    'original_title' : 'Original Title',
    'overview' : 'Overview',
    'popularity' : 'Popularity',
    'production_companies' : 'Production Companies',
    'production_countries' : 'Production Countries',
    'release_date' : 'Release Date',
    'revenue' : 'Revenue',
    'runtime' : 'Runtime',
    'spoken_languages' : 'Spoken Languages',
    'status' : 'Status',
    'tagline' : 'Tagline',
    'title' : 'Title',
    'vote_average' : 'Vote Average',
    'vote_count' : 'Vote Count'
}
df.rename(columns = column_mapping, inplace = True)
dfilter=df.filter(items = ['Title', 'Budget', 'Revenue', 'Popularity', 'Vote Average', 'Vote Count']) #filtering data relevant to the success of a movie in database
dfilter
# Out:
#                                          Title     Budget     Revenue  \
# 0                                       Avatar  237000000  2787965087
# 1     Pirates of the Caribbean: At World's End  300000000   961000000
# 2                                      Spectre  245000000   880674609
# 3                        The Dark Knight Rises  250000000  1084939099
# 4                                  John Carter  260000000   284139100
# ...                                        ...        ...         ...
# 4774                            Pink Narcissus      27000           0
# 4781                                 Dry Spell      22000           0
# 4788                            Pink Flamingos      12000     6000000
# 4792                                      Cure      20000       99000
# 4798                               El Mariachi     220000     2040920
#
#       Popularity  Vote Average  Vote Count
# 0     150.437577           7.2       11800
# ...

# %% [markdown]
# ### APPLYING THE CONDITION NECESSARY TO DETERMINE THE SUCCESS OF A MOVIE.
# NOTE: A movie is said to be succesful only if the revenue obtained is 3 times or greater than the budget in production and other purposes. Here We have used 10 times as the condition to filter out the hyper succesful movies and study their patterns.

# %%
condition = 10*dfilter['Budget']<dfilter['Revenue'] #A movie is said to be succesful if the revenue is 3 times or greater than that of the budget.
drevbud = dfilter[condition]
drevbud
# Out:
#                                               Title     Budget     Revenue  \
# 0                                            Avatar  237000000  2787965087
# 28                                   Jurassic World  150000000  1513528810
# 328                                    Finding Nemo   94000000   940335536
# 329   The Lord of the Rings: The Return of the King   94000000  1118888979
# 330           The Lord of the Rings: The Two Towers   79000000   926287400
# ...                                             ...        ...         ...
# 4724                                     Eraserhead      10000     7000000
# 4738                                             Pi      60000     3221152
# 4742                                  Super Size Me      65000    28575078
# 4773                                         Clerks      27000     3151130
# 4788                                 Pink Flamingos      12000     6000000
#
#       Popularity  Vote Average  Vote Count
# ...

# %% [markdown]
# ### CREATING AN EXTRA COLUMN FOR PROFIT PERCENTAGE:-

# %%
profit_list = []
for i in drevbud.index:
    profit_percentage = int((((drevbud['Revenue'][i] - drevbud['Budget'][i])/drevbud['Budget'][i])*100).round())
    profit_list.append(profit_percentage)
drevbud['Profit_Percentage_%'] = profit_list
drevbud
# Out:
# C:\Users\agraw\AppData\Local\Temp\ipykernel_22568\926986737.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drevbud['Profit_Percentage_%'] = profit_list
#                                               Title     Budget     Revenue  \
# 0                                            Avatar  237000000  2787965087
# 28                                   Jurassic World  150000000  1513528810
# 328                                    Finding Nemo   94000000   940335536
# 329   The Lord of the Rings: The Return of the King   94000000  1118888979
# 330           The Lord of the Rings: The Two Towers   79000000   926287400
# ...                                             ...        ...         ...
# ...

# %% [markdown]
# ### USING THE info(),describe() and corr() FUNCTIONS:-

# %%
drevbud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 266 entries, 0 to 4788
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                266 non-null    object
#  1   Budget               266 non-null    int64
#  2   Revenue              266 non-null    int64
#  3   Popularity           266 non-null    float64
#  4   Vote Average         266 non-null    float64
#  5   Vote Count           266 non-null    int64
#  6   Profit_Percentage_%  266 non-null    int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 24.7+ KB

# %%
drevbud.describe()
# Out:
#              Budget       Revenue  Popularity  Vote Average    Vote Count  \
# count  2.660000e+02  2.660000e+02  266.000000    266.000000    266.000000
# mean   1.249432e+07  2.058925e+08   44.754443      6.817293   1546.936090
# std    2.317304e+07  2.839105e+08   70.520932      0.835533   1896.106571
# min    1.000000e+04  1.776935e+06    0.132878      4.100000      5.000000
# 25%    1.200000e+06  3.410066e+07   17.030319      6.300000    361.500000
# 50%    5.000000e+06  1.094906e+08   30.258012      6.900000    874.000000
# 75%    1.400000e+07  2.715965e+08   50.108097      7.400000   1886.000000
# max    2.370000e+08  2.787965e+09  875.581305      8.400000  11800.000000
#
#        Profit_Percentage_%
# count         2.660000e+02
# mean          1.038331e+04
# std           8.297218e+04
# min           9.000000e+02
# 25%           1.144250e+03
# 50%           1.658500e+03
# 75%           2.984000e+03
# max           1.288939e+06

# %%
df_corr = drevbud.select_dtypes(np.number)

dff = df_corr.corr()
dff
# Out:
#                        Budget   Revenue  Popularity  Vote Average  Vote Count  \
# Budget               1.000000  0.937481    0.503553      0.084598    0.715691
# Revenue              0.937481  1.000000    0.537761      0.140802    0.758712
# Popularity           0.503553  0.537761    1.000000      0.155077    0.617336
# Vote Average         0.084598  0.140802    0.155077      1.000000    0.393252
# Vote Count           0.715691  0.758712    0.617336      0.393252    1.000000
# Profit_Percentage_% -0.057632 -0.012349   -0.006930     -0.083436   -0.024893
#
#                      Profit_Percentage_%
# Budget                         -0.057632
# Revenue                        -0.012349
# Popularity                     -0.006930
# Vote Average                   -0.083436
# Vote Count                     -0.024893
# Profit_Percentage_%             1.000000

# %% [markdown]
# ### SORTING THE DATASET ACCORDING TO THE DESCENDING PROFIT PERCENTAGE:-

# %%
details = drevbud.sort_values(by = 'Profit_Percentage_%',ascending = False)
details.reset_index(inplace=True)
details.drop("index",axis=1,inplace=True) 
details
# Out:
#                        Title     Budget     Revenue  Popularity  Vote Average  \
# 0        Paranormal Activity      15000   193355800   47.456823           5.9
# 1    The Blair Witch Project      60000   248000000   41.690578           6.3
# 2                 Eraserhead      10000     7000000   20.399578           7.5
# 3             Pink Flamingos      12000     6000000    4.553644           6.2
# 4              Super Size Me      65000    28575078   10.400603           6.6
# ..                       ...        ...         ...         ...           ...
# 261           Jurassic World  150000000  1513528810  418.708552           6.5
# 262                 Cry_Wolf    1000000    10047674    6.926926           5.6
# 263            Godzilla 2000    1000000    10037390    3.322721           5.9
# 264    Kissing Jessica Stein    1000000    10013424    3.990215           5.9
# 265             Finding Nemo   94000000   940335536   85.688789           7.6
#
# ...

# %% [markdown]
# # DATA VISUALISATION:-

# %% [markdown]
# ### Plotting a heat map to show co-relation amongst the parameters:-
# 1. The value that is positive directly varies witht the respective parameter.
# 2. The value that is negative inversely varies with the respective parameter.
# 3. The value always lies in between 0 to 1.

# %%
sns.heatmap(dff,cmap = 'PuBuGn', vmin = -1,vmax = 1,annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### Plotting a bar graph to show the profit percentage for the top 10 most profitable movies in the 5000 movie dataset:-
# NOTE: The percentage will be read by multiplying the y-axis values with 10^6.

# %%
plt.bar(details['Title'].head(10), details['Profit_Percentage_%'].head(10), edgecolor='white', linewidth=0.4, width = 0.3)
plt.xlabel('Title')
plt.ylabel('Profit_Percentage_%')
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# ### Plotting a density graph with respect to the revenue parameter.
# NOTE: The density reading is given by multiplying the visible x and y-axis value with 10^9.

# %%
details['Revenue'].plot(kind = 'density')
plt.xlabel('Revenues made by movies')
print('This distribution has skew',details['Revenue'].skew())
print('This distribution has kurtosis',details['Revenue'].kurt())
# Out:
# This distribution has skew 4.04664373890046
# This distribution has kurtosis 27.474743452706587

# %% [markdown]
# ###### Majority of data lies between 0 to 1 and the density peaks at 2.5 x 10^9.

# %%
details_top10 = details.head(10)
details_top10.plot.pie(y='Popularity', labels=df['Title'], autopct='%1.1f%%', startangle=90, legend=False)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the plot
plt.show()
